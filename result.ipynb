# %% [markdown]
# # ***Import & Installation***

# %%
# !git clone https://github.com/maryamdkh/SpeechCARE_Acoustic_Explainability_Framework.git

# %%
# !pip --q install praat-parselmouth
# !pip --q install librosa
# !pip --q install stanza
# !pip --q install whisperx

# %%
from google.colab import drive
import pandas as pd
from IPython.display import Image
import warnings
import os

# %% [markdown]
# # ***Config***

# %%
drive.mount("/content/drive")
warnings.filterwarnings('ignore')
samples_df = pd.read_csv("data/samples_df.csv")
# Out:
# Mounted at /content/drive

# %%
model_id = "large-v3"
compute_type = "int8"
CHECKPOINTS_FILE = "checkpoints/model_best.pt"

# %% [markdown]
# #***Samples***

# %% [markdown]
# ##***lxbg: ADRD***

# %%
AUDIO_PATH = os.path.join("data",samples_df.loc[0,"path"].split("/")[-1])
DEMOGRAPHIC_INFO = float(samples_df.loc[0,"age"])
FIG_SAVE_PATH = f"figs/{samples_df.loc[0,'uid']}_spectrogram.png"
WORD_SEGMENTS_PATH = f"data/{samples_df.loc[0,'uid']}_WhisperX_{model_id}_{compute_type}_charLevel.json"

# %%
# !python SpeechCARE_Acoustic_Explainability_Framework/test/test.py --model_checkpoint $CHECKPOINTS_FILE \
                                                                  --audio_path $AUDIO_PATH \
                                                                  --demography_info $DEMOGRAPHIC_INFO \
                                                                  --fig_save_path $FIG_SAVE_PATH \
                                                                  --word_segments $WORD_SEGMENTS_PATH
# Out:
# 2025-03-03 06:34:27.571279: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740983667.614388   14656 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740983667.627493   14656 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 06:34:27.677996: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
Image(filename=FIG_SAVE_PATH)

# %% [markdown]
# ##***qbce: Control***

# %%
AUDIO_PATH = os.path.join("data",samples_df.loc[1,"path"].split("/")[-1])
DEMOGRAPHIC_INFO = float(samples_df.loc[1,"age"])
FIG_SAVE_PATH = f"figs/{samples_df.loc[1,'uid']}_spectrogram.png"
WORD_SEGMENTS_PATH = f"data/{samples_df.loc[1,'uid']}_WhisperX_{model_id}_{compute_type}_charLevel.json"

# %%
# !python SpeechCARE_Acoustic_Explainability_Framework/test/test.py --model_checkpoint $CHECKPOINTS_FILE \
                                                                  --audio_path $AUDIO_PATH \
                                                                  --demography_info $DEMOGRAPHIC_INFO \
                                                                  --fig_save_path $FIG_SAVE_PATH \
                                                                  --word_segments $WORD_SEGMENTS_PATH
# Out:
# 2025-03-03 06:50:04.279663: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740984604.313107   18706 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740984604.323428   18706 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 06:50:04.362952: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
Image(filename=FIG_SAVE_PATH)

# %% [markdown]
# ## ***qnvo: MCI***

# %%
AUDIO_PATH = os.path.join("data",samples_df.loc[2,"path"].split("/")[-1])
DEMOGRAPHIC_INFO = float(samples_df.loc[2,"age"])
FIG_SAVE_PATH = f"figs/{samples_df.loc[2,'uid']}_spectrogram.png"
WORD_SEGMENTS_PATH = f"data/{samples_df.loc[2,'uid']}_WhisperX_{model_id}_{compute_type}_charLevel.json"

# %%
# !python SpeechCARE_Acoustic_Explainability_Framework/test/test.py --model_checkpoint $CHECKPOINTS_FILE \
                                                                  --audio_path $AUDIO_PATH \
                                                                  --demography_info $DEMOGRAPHIC_INFO \
                                                                  --fig_save_path $FIG_SAVE_PATH \
                                                                  --word_segments $WORD_SEGMENTS_PATH
# Out:
# 2025-03-03 06:51:33.651055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740984693.685890   19112 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740984693.699518   19112 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 06:51:33.747287: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
Image(filename=FIG_SAVE_PATH)
